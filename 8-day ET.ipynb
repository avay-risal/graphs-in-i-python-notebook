# %%
# importing the required module
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
import datetime as dt
import pylab as pl
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import FuncFormatter

#plt.style.use('ggplot')
plt.style.use('default')

#open csv data
et = pd.read_csv('D:/graph_data/ET_graph.csv')
# print(et.head(5))


#change date format
et['date_8'] = pd.to_datetime(et['date_8'])
et['date_m'] = pd.to_datetime(et['date_m'])
et['date_s'] = pd.to_datetime(et['date_s'])
# et['date_y'] = pd.to_datetime(et['date_y'])


SWAT_8= et["SWAT_8"]
MODIS_8=et["MODIS_8"]
SWAT_m= et["SWAT_m"]
MODIS_m=et["MODIS_m"]
SWAT_s= et["SWAT_s"]
MODIS_s=et["MODIS_s"]
SWAT_y= et["SWAT_y"]
MODIS_y=et["MODIS_y"]

date_8= et["date_8"]
date_m= et["date_m"]
date_s= et["date_s"]
date_y= et["date_y"]

period=et["period"]
# print(period)

######################################################################################################################
plt.figure(1)
ax=plt.subplot()

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(12)


ax.plot(date_8, SWAT_8, color='green', label="SWAT")
ax.plot(date_8, MODIS_8, color='red',  label='MODIS')



ax.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/8-days)",size = 12, fontweight='bold')
plt.xlabel("Years",size = 12, fontweight='bold')

fig1 = plt.gcf()
fig1.set_size_inches(10,5)
fig1.savefig('Figure_6_8-daysET', dpi=800)
#############################################################################################################
plt.figure(2)
ax1=plt.subplot()

for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(12)


ax1.plot(date_m, SWAT_m, color='green', label="SWAT")
ax1.plot(date_m, MODIS_m, color='red',  label='MODIS')



ax1.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/month)",size = 12, fontweight='bold')
plt.xlabel("Years",size = 12, fontweight='bold')

fig2 = plt.gcf()
fig2.set_size_inches(10,5)
fig2.savefig('Figure_7_monthET', dpi=800)
#############################################################################################################
plt.figure(3)
ax2=plt.subplot()

for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontsize(12)


ax2.plot(date_s, SWAT_s, color='green', label="SWAT")
ax2.plot(date_s, MODIS_s, color='red',  label='MODIS')



ax2.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/season)",size = 12, fontweight='bold')
plt.xlabel("Years",size = 12, fontweight='bold')

fig3 = plt.gcf()
fig3.set_size_inches(10,5)
fig3.savefig('Figure_8_seasonET', dpi=800)
#############################################################################################################
plt.figure(4)
ax3=plt.subplot()

height_SWAT= [198.83,191.59,194.17,188.29,188.06,187.21,180.39,180.26,178.33]
height_MODIS=[216.44,214.86,217.99,219.12,219.26,219.27,214.53,219.79,220.93]


bars=[2010,2011,2012,2013,2014,2015,2016,2017,2018]
years = np.arange(len(bars))

for label in (ax3.get_xticklabels() + ax3.get_yticklabels()):
    label.set_fontsize(12)

plt.ylim(0.,300)
width=0.2

plt.bar(years-width/2, height_SWAT,  label='SWAT', width=width, color="green")
plt.bar(years+width/2, height_MODIS,  color='red', width=width, label='MODIS')

plt.xticks(years,bars)

plt.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/year)",size = 12, fontweight='bold')
plt.xlabel("Years",size = 12, fontweight='bold')

fig4 = plt.gcf()
fig4.set_size_inches(10,5)
fig4.savefig('Figure_yearET', dpi=800)
#############################################################################################################
