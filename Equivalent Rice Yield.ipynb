# %%
# importing the required module
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
import datetime as dt
import pylab as pl
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import FuncFormatter

#plt.style.use('ggplot')
plt.style.use('default')

#open csv data
yld=pd.read_csv('D:/graph_data/equivalent_crop_yield.csv')
print (yld.head(5))


# #change date format
# gw['date_1'] = pd.to_datetime(gw['date_1'])
# gw['date_2'] = pd.to_datetime(gw['date_2'])
# gw['date_3'] = pd.to_datetime(gw['date_3'])
# gw['date_4'] = pd.to_datetime(gw['date_4'])
# gw['date_5'] = pd.to_datetime(gw['date_5'])
# gw['date_6'] = pd.to_datetime(gw['date_6'])
# gw['date_7'] = pd.to_datetime(gw['date_7'])
# gw['date_8'] = pd.to_datetime(gw['date_8'])


# # print(gw.head())


date= yld["date"]
date1= yld["date1"]
date2= yld["date2"]
date3= yld["date3"]


for col in yld.columns:
    print(col)

ricewheat= yld["rice-wheat"]
ricevegrice= yld["rice-vegetable-rice"]
ricelentil= yld["rice-lentil"]
ricemaize= yld["rice-irrigated maize"]
ricewheat1= yld["rice-wheat1"]
ricewheatmung= yld["rice-wheat-mungbean"]
ricewheat2= yld["rice-wheat2"]
ricewheatpotato= yld["rice-wheat-potato"]


barWidth = 0.25

br1 = np.arange(len(ricewheat))
br2 = [x + barWidth for x in br1]

fig, axs = plt.subplots(4)
#####################################################################################################################
ax1= plt.subplot(2,2,1)

for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(16)


#br3 = [x + barWidth for x in br2]
plt.ylim (0,20)
plt.bar(br1, ricewheat, color ='r', width = barWidth, edgecolor ='grey', label ='Rice-Wheat')
plt.bar(br2, ricevegrice, color ='g', width = barWidth, edgecolor ='grey', label ='Rice-Vegetable-Rice')

plt.xlabel('Periods', fontweight ='bold', fontsize = 15)
plt.ylabel('Equivalent Rice Yield (ton/ha)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(3)],['2000-2020', '2021-2035', '2036-2050'])

plt.legend(fontsize=16 , loc=9, frameon=False)
#####################################################################################################################
ax2= plt.subplot(2,2,2)

for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim (0,20)
plt.bar(br1, ricelentil, color ='r', width = barWidth, edgecolor ='grey', label ='Rice-Lentil')
plt.bar(br2, ricemaize, color ='g', width = barWidth, edgecolor ='grey', label ='Rice-Irrigated Maize')

plt.xlabel('Periods', fontweight ='bold', fontsize = 15)
plt.ylabel('Equivalent Rice Yield (ton/ha)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(3)],['2000-2020', '2021-2035', '2036-2050'])

plt.legend(fontsize=16 , loc=9, frameon=False)

##################################################################################################################### 
ax3= plt.subplot(2,2,3)

for label in (ax3.get_xticklabels() + ax3.get_yticklabels()):
    label.set_fontsize(16)
    
plt.ylim (0,20)    
plt.bar(br1, ricewheat1, color ='r', width = barWidth, edgecolor ='grey', label ='Rice-Wheat')
plt.bar(br2, ricewheatmung, color ='g', width = barWidth, edgecolor ='grey', label ='Rice-Wheat-Mung')

plt.xlabel('Periods', fontweight ='bold', fontsize = 15)
plt.ylabel('Equivalent Rice Yield (ton/ha)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(3)],['2000-2020', '2021-2035', '2036-2050'])

plt.legend(fontsize=16 , loc=9, frameon=False)

#####################################################################################################################
ax4= plt.subplot(2,2,4)

for label in (ax4.get_xticklabels() + ax4.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim (0,20)
plt.bar(br1, ricewheat2, color ='r', width = barWidth, edgecolor ='grey', label ='Rice-Wheat')
plt.bar(br2, ricewheatpotato, color ='g', width = barWidth, edgecolor ='grey', label ='Rice-Wheat-Potato')

plt.xlabel('Periods', fontweight ='bold', fontsize = 15)
plt.ylabel('Equivalent Rice Yield (ton/ha)', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(3)],['2000-2020', '2021-2035', '2036-2050'])

plt.legend(fontsize=16 , loc=9, frameon=False)

#####################################################################################################################
fig = plt.gcf()
fig.set_size_inches(20, 18)
fig.savefig('Rice Equivalent_yield.png', dpi=600)
# Out:
#         date  rice-wheat  rice-vegetable-rice      date1  rice-wheat1  \
# 0  2000-2020         7.3                11.72  2000-2020          8.8
# 1  2021-2035         6.5                 8.26  2021-2035          7.6
# 2  2035-2050         6.0                 8.56  2035-2050          7.1
#
#    rice-wheat-mungbean      date2  rice-wheat2  rice-wheat-potato      date3  \
# 0                19.28  2000-2020        8.241              11.55  2000-2020
# 1                14.85  2021-2035        7.557              10.53  2021-2035
# 2                13.27  2035-2050        7.119               9.35  2035-2050
#
#    rice-lentil  rice-irrigated maize
# 0          7.4                   8.0
# 1          6.7                   6.5
# 2          6.5                   5.5
# date
# rice-wheat
# rice-vegetable-rice
# date1
# rice-wheat1
# rice-wheat-mungbean
# date2
# rice-wheat2
# rice-wheat-potato
# date3
# rice-lentil
# rice-irrigated maize
