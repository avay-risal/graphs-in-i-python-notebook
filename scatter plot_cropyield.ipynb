# %%
# importing the required module
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
import datetime as dt
import pylab as pl
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from matplotlib.ticker import EngFormatter

#plt.style.use('ggplot')
plt.style.use('default')

#open csv data
yieldd = pd.read_csv('D:/graph_data/crop_calibration.csv')

obs5 = yieldd['Observed_C']
sim5 = yieldd['Simulated_C']
obs10 = yieldd['Observed_S']
sim10 = yieldd['Simulated_S']


print(yieldd.head(5))
# print (obs5)
#print (obs10)
# print (sim10)
#print (sim5)
# 
############################################
ax= plt.subplot(121)
plt.plot(obs10, sim10, ".", ms=20, mec="k")
z = np.polyfit(obs10, sim10, 1)
p = np.poly1d(z)(obs10)

plt.plot(obs10,p,"r--",lw=2)
text = "$R^2 = 0.552$ \nNSE= 0.450"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=20, verticalalignment='top')

# formatter0 = EngFormatter(unit='kg/ha$')
# ax.yaxis.set_major_formatter(formatter0)
# ax.xaxis.set_major_formatter(formatter0)

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(20)
    
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(2)
    


plt.ylabel("simulated yield(kg/ha) ", size=20, fontweight='bold')
plt.xlabel("Observed yield(kg/ha)", size=20, fontweight='bold')
plt.title("calibration",size=25, fontweight='bold')


#########################################################
ax1=plt.subplot(122)
plt.plot(obs10, sim10, ".", ms=20, mec="k")
z = np.polyfit(obs10, sim10, 1)
p = np.poly1d(z)(obs10)



plt.plot(obs10,p,"r--",lw=2)
text = "$R^2 = 0.621 $\nNSE= 0.07"
plt.gca().text(0.05, 0.95, text,transform=plt.gca().transAxes,
     fontsize=20, verticalalignment='top')

# formatter1 = EngFormatter(unit='$kg/ha$')
# ax1.yaxis.set_major_formatter(formatter1)
# ax1.xaxis.set_major_formatter(formatter1)

for label in (ax1.get_xticklabels() + ax1.get_yticklabels()):
    label.set_fontsize(20)
    
for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.ylabel("simulated yield (kg/ha)" , size=20, fontweight='bold')
plt.xlabel("Observed yield (kg/ha)", size=20, fontweight='bold')
plt.title("validation", size=25, fontweight='bold')

##################################################################


fig = plt.gcf()
fig.set_size_inches(20,9)
fig.savefig('Figure5_scatterplot_cropyield.png', dpi=700)

# plt.savefig('scatterPlot.png') # save as png
# Out:
#    Year   Observed_C  Simulated_C   Observed_S  Simulated_S
# 0  2008  3050.908333    3449.0900  3254.900000  3297.861667
# 1  2009  4402.633333    4790.1625  3313.183333  4360.261667
# 2  2010  4530.968750    4570.0550  4228.343750  4493.721667
# 3  2011  4245.156250    5425.7700  4073.668750  4249.286667
# 4  2012  4131.391667    5640.5700  3952.618750  5269.700000
