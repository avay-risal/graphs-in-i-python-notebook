# %%
# importing the required module
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
import datetime as dt
import pylab as pl
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import FuncFormatter

#plt.style.use('ggplot')
plt.style.use('default')

#open csv data
et = pd.read_csv('D:/graph_data/ET_graph.csv')
# print(et.head(5))


#change date format
et['date_8'] = pd.to_datetime(et['date_8'])
et['date_m'] = pd.to_datetime(et['date_m'])
et['date_s'] = pd.to_datetime(et['date_s'])
# et['date_y'] = pd.to_datetime(et['date_y'])


SWAT_8= et["SWAT_8"]
MODIS_8=et["MODIS_8"]
SWAT_m= et["SWAT_m"]
MODIS_m=et["MODIS_m"]
SWAT_s= et["SWAT_s"]
MODIS_s=et["MODIS_s"]
SWAT_y= et["SWAT_y"]
MODIS_y=et["MODIS_y"]

SWAT_mon= et["SWAT_mon"]
MODIS_mon= et["MODIS_mon"]
SWAT_se=et["SWAT_se"]
MODIS_se=et["MODIS_se"]

date_8= et["date_8"]
date_m= et["date_m"]
date_s= et["date_s"]
date_y= et["date_y"]

period=et["period"]
month=et["month_1"]
season=et["season_1"]

period=et["period"]



plt.figure(5)
ax5=plt.subplot()

height_Sm= [6.92,9.80,14.75,17.12,21.98,23.12,22.97,20.52,19.55,13.49,9.84,7.38]
height_Mm=[18.14,18.45,18.34,15.39,18.35,20.49,21.01,19.93,18.47,14.46,17.01,17.97]

bars1= ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
months= np.arange(len(bars1))

for label in (ax5.get_xticklabels() + ax5.get_yticklabels()):
    label.set_fontsize(12)

# plt.ylim(0.,300)
width=0.2

plt.bar(months-width/2, height_Sm,  label='SWAT', width=width, color="green")
plt.bar(months+width/2, height_Mm,  color='red', width=width, label='MODIS')

plt.xticks(months,bars1)

plt.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/month)",size = 12, fontweight='bold')
plt.xlabel("Months",size = 12, fontweight='bold')

fig5 = plt.gcf()
fig5.set_size_inches(10,5)
fig5.savefig('Figure_avg_month_ET', dpi=800)
#############################################################################################################
plt.figure(6)
ax6=plt.subplot()


height_S= [47.8,89.9,49.8]
height_M=[69.8, 80.9,67.4]

bars= ["Spring", "Summer", "Fall"]
seasons= np.arange(len(bars))

for label in (ax6.get_xticklabels(labels) + ax6.get_yticklabels()):
    label.set_fontsize(12)

width=0.2

plt.bar(seasons-width/2, height_S,  label='SWAT', width=width, color="green")
plt.bar(seasons+width/2, height_M,  color='red', width=width, label='MODIS')

plt.xticks(seasons,bars)

plt.legend(fontsize=12 , loc='best', frameon=False)

plt.ylabel("Evapotranspiration (mm/season)",size = 12, fontweight='bold')
plt.xlabel("Season",size = 12, fontweight='bold')

fig6 = plt.gcf()
fig6.set_size_inches(10,5)
fig6.savefig('Figure_avg_season_ET', dpi=800)
